# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
import statsmodels.formula.api as smf

# %%
candidates_df = pd.read_csv('../data/candidates_clean.csv', dtype = {'district': 'str'})

# %%
candidates_df.head()
# Out:
#         candidate_name party  incumbent  winner  perc_vote  money_raised  \
# 0           Jerry Carl     R          0       1       64.9       1971321
# 1       James Averhart     D          0       0       35.0         80095
# 2          Barry Moore     R          0       1       65.3        650807
# 3  Phyllis Harvey-Hall     D          0       0       34.6         56050
# 4        Mike D Rogers     R          1       1       67.5       1193111
#
#    money_spent state_name district state_dist  perc_vote_max  winner_bool
# 0      1859349         AL       01       AL01           64.9            1
# 1        78973         AL       01       AL01           64.9            0
# 2       669368         AL       02       AL02           65.3            1
# 3        55988         AL       02       AL02           65.3            0
# 4      1218564         AL       03       AL03           67.5            1

# %%
grouped_candidates = candidates_df.groupby(['state_name', 'state_dist'])


# Calculate the total cash raised for each district
total_cash_raised_per_district = grouped_candidates['money_raised'].transform('sum')
total_cash_spent_per_district = grouped_candidates['money_spent'].transform('sum')

# Calculate the percentage of Cash Raised for each candidate
candidates_df['perc_money_raised'] = (candidates_df['money_raised'] / total_cash_raised_per_district) * 100
candidates_df['perc_money_spent'] = (candidates_df['money_spent'] / total_cash_spent_per_district) * 100
# candidates_df['raised_spent_diff'] = candidates_df['money_raised'] - candidates_df['money_spent']

# %% [markdown]
# We create a function that will
# * Generate random test-train splits, putting 10% of the data in a test set and 90% in a training set
# * build the regression model
# * predict on the test set and calculate the accuracy
# * use a different seed each time (this is probably overkill!)

# %%
import time
t = 1000 * time.time() # current time in milliseconds
np.random.seed(int(t) % 2**32)

def check_acc():

    t = 1000 * time.time() # current time in milliseconds
    np.random.seed(int(t) % 2**32)

    # Define the proportion of data to use for the test set (e.g., 80% train, 20% test)
    test_size = 0.1

    # Generate a boolean mask for selecting rows for the test set
    test_mask = np.random.rand(len(candidates_df)) < test_size

    # Split the data into training and test sets
    train_data = candidates_df[~test_mask]
    test_data = candidates_df[test_mask]

    # reset the index of the new DataFrames
    train_data = train_data.reset_index(drop=True)
    test_data = test_data.reset_index(drop=True)
    model = smf.logit('winner_bool ~ perc_money_spent + incumbent', data = train_data).fit()
    preds = (model.predict(test_data) > 0.5).astype(int)
    return (test_data['winner'] == preds).sum()/len(test_data['winner'])

# %% [markdown]
# Run the function 100 times and store the accuracies in an array

# %%
accuracies = []
for i in range(1000):
    accuracies.append(check_acc())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.170315
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.171656
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.180416
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.175478
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.178007
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.182190
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.177272
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.172232
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.169242
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.177134
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.165486
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.163354
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.168945
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.176364
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.176823
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.181162
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.162452
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.166140
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.175411
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.173626
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.162338
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.171869
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.162559
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.174843
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.164713
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.181657
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.178382
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.176133
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.163945
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.181026
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.168974
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.172289
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.179267
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.177714
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.169928
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.172180
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.175929
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.163071
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.169567
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.173199
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.177533
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.171955
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.167898
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.173428
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.177129
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.171186
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.179202
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.172879
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.176401
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.174864
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.172977
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.176781
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.175883
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.168971
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.168395
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.177212
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.167942
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.171329
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.169966
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.175834
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.178168
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.170577
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.179093
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.162126
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.166412
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.164887
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.162921
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.172120
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.173392
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.176879
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.177303
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.174684
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.175991
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.179585
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.169037
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.177484
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.166403
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.175044
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.182964
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.173810
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.175462
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.174461
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.163914
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.174560
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.166620
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.170475
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.170778
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.161167
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.178421
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.180460
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.177967
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.179671
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.172763
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.172902
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.159937
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.168751
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.173365
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.171453
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.172055
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.173237
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.174816
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.174585
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.160967
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.175855
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.168190
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.176876
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.182970
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.176553
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.165754
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.173806
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.179346
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.180843
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.170559
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.165910
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.174605
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.180081
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.167156
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.163088
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.172089
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.181480
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.171968
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.180808
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.178202
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.179625
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.172866
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.167375
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.175432
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.162312
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.176960
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.175102
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.178675
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.176704
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.178305
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.163053
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.174264
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.168263
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.170907
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.162959
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.171251
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.172088
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.171548
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.170734
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.170332
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.177771
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.162996
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.177297
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.165026
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.170368
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.178077
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.180640
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.173430
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.166569
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.169002
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.170760
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.174283
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.172990
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.167327
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.178113
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.170665
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.172128
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.171029
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.171221
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.161273
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.